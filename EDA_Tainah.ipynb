# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
URL = 'https://raw.githubusercontent.com/tainahguerras/Estatistica-ADA-Santander/main/data/study_performance.csv?token=GHSAT0AAAAAACNBYNJAVU73SXTIPDH3PETKZQLHYKQ'
data = pd.read_csv(URL)

# %%
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
# Variáveis categóricas

vars_cat = ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']

for var in vars_cat:
    print(var)
    print(sorted(data[var].unique()),'\n')
# Out:
# gender
# ['female', 'male']
#
# race_ethnicity
# ['group A', 'group B', 'group C', 'group D', 'group E']
#
# parental_level_of_education
# ["associate's degree", "bachelor's degree", 'high school', "master's degree", 'some college', 'some high school']
#
# lunch
# ['free/reduced', 'standard']
#
# test_preparation_course
# ['completed', 'none']

# %%
# Variáveis quantitativas

vars_quant = ['math_score', 'reading_score', 'writing_score']
data[vars_quant].describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print('Desvio padrão:', data['math_score'].std())

sns.histplot(data['math_score'], bins=20, kde=True)
plt.title('Distribuição das Pontuações em Matemática')
plt.xlabel('Pontuação')
plt.ylabel('Contagem')
plt.show()
# Out:
# Desvio padrão: 15.163080096009452

# %%
print('Desvio padrão:', data['reading_score'].std())

sns.histplot(data['reading_score'], bins=20, kde=True)
plt.title('Distribuição das Pontuações em Leitura')
plt.xlabel('Pontuação')
plt.ylabel('Contagem')
plt.show()
# Out:
# Desvio padrão: 14.600191937252216

# %%
print('Desvio padrão:', data['writing_score'].std())

sns.histplot(data['writing_score'], bins=20, kde=True)
plt.title('Distribuição das Pontuações em Escrita')
plt.xlabel('Pontuação')
plt.ylabel('Contagem')
plt.show()
# Out:
# Desvio padrão: 15.19565701086965
